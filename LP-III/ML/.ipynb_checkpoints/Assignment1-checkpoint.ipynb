# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
data = pd.read_csv("uber.csv")

# %%
data
# Out:
#         Unnamed: 0                            key  fare_amount  \
# 0         24238194    2015-05-07 19:52:06.0000003          7.5
# 1         27835199    2009-07-17 20:04:56.0000002          7.7
# 2         44984355   2009-08-24 21:45:00.00000061         12.9
# 3         25894730    2009-06-26 08:22:21.0000001          5.3
# 4         17610152  2014-08-28 17:47:00.000000188         16.0
# ...            ...                            ...          ...
# 199995    42598914   2012-10-28 10:49:00.00000053          3.0
# 199996    16382965    2014-03-14 01:09:00.0000008          7.5
# 199997    27804658   2009-06-29 00:42:00.00000078         30.9
# 199998    20259894    2015-05-20 14:56:25.0000004         14.5
# 199999    11951496   2010-05-15 04:08:00.00000076         14.1
#
#                 pickup_datetime  pickup_longitude  pickup_latitude  \
# 0       2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1       2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2       2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3       2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4       2014-08-28 17:47:00 UTC        -73.925023        40.744085
# ...                         ...               ...              ...
# 199995  2012-10-28 10:49:00 UTC        -73.987042        40.739367
# 199996  2014-03-14 01:09:00 UTC        -73.984722        40.736837
# 199997  2009-06-29 00:42:00 UTC        -73.986017        40.756487
# 199998  2015-05-20 14:56:25 UTC        -73.997124        40.725452
# 199999  2010-05-15 04:08:00 UTC        -73.984395        40.720077
#
#         dropoff_longitude  dropoff_latitude  passenger_count
# 0              -73.999512         40.723217                1
# 1              -73.994710         40.750325                1
# 2              -73.962565         40.772647                1
# 3              -73.965316         40.803349                3
# 4              -73.973082         40.761247                5
# ...                   ...               ...              ...
# 199995         -73.986525         40.740297                1
# 199996         -74.006672         40.739620                1
# 199997         -73.858957         40.692588                2
# 199998         -73.983215         40.695415                1
# 199999         -73.985508         40.768793                1
#
# [200000 rows x 9 columns]

# %%
data.head()
# Out:
#    Unnamed: 0                            key  fare_amount  \
# 0    24238194    2015-05-07 19:52:06.0000003          7.5
# 1    27835199    2009-07-17 20:04:56.0000002          7.7
# 2    44984355   2009-08-24 21:45:00.00000061         12.9
# 3    25894730    2009-06-26 08:22:21.0000001          5.3
# 4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         200000 non-null  int64
#  1   key                200000 non-null  object
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  object
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 13.7+ MB

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'key', 'fare_amount', 'pickup_datetime',
#        'pickup_longitude', 'pickup_latitude', 'dropoff_longitude',
#        'dropoff_latitude', 'passenger_count'],
#       dtype='object')

# %%
data.drop(['Unnamed: 0', 'key'], axis=1, inplace=True)

# %%
data.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1          7.7  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2         12.9  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3          5.3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4         16.0  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
data.shape
# Out:
# (200000, 7)

# %%
data.dtypes
# Out:
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
data.dropna(axis=0, inplace=True)

# %%
data.isnull().sum()
# Out:
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# dtype: int64

# %%
data.dtypes
# Out:
# fare_amount          float64
# pickup_datetime       object
# pickup_longitude     float64
# pickup_latitude      float64
# dropoff_longitude    float64
# dropoff_latitude     float64
# passenger_count        int64
# dtype: object

# %%
data.pickup_datetime = pd.to_datetime(data.pickup_datetime, errors='coerce')

# %%
data.dtypes
# Out:
# fare_amount                      float64
# pickup_datetime      datetime64[ns, UTC]
# pickup_longitude                 float64
# pickup_latitude                  float64
# dropoff_longitude                float64
# dropoff_latitude                 float64
# passenger_count                    int64
# dtype: object

# %%
data = data.assign(hour = data.pickup_datetime.dt.hour,
                  day = data.pickup_datetime.dt.day,
                  month = data.pickup_datetime.dt.month,
                  year = data.pickup_datetime.dt.year,
                  dayofweek = data.pickup_datetime.dt.dayofweek)

# %%
data
# Out:
#         fare_amount           pickup_datetime  pickup_longitude  \
# 0               7.5 2015-05-07 19:52:06+00:00        -73.999817
# 1               7.7 2009-07-17 20:04:56+00:00        -73.994355
# 2              12.9 2009-08-24 21:45:00+00:00        -74.005043
# 3               5.3 2009-06-26 08:22:21+00:00        -73.976124
# 4              16.0 2014-08-28 17:47:00+00:00        -73.925023
# ...             ...                       ...               ...
# 199995          3.0 2012-10-28 10:49:00+00:00        -73.987042
# 199996          7.5 2014-03-14 01:09:00+00:00        -73.984722
# 199997         30.9 2009-06-29 00:42:00+00:00        -73.986017
# 199998         14.5 2015-05-20 14:56:25+00:00        -73.997124
# 199999         14.1 2010-05-15 04:08:00+00:00        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 0             40.738354         -73.999512         40.723217                1
# 1             40.728225         -73.994710         40.750325                1
# 2             40.740770         -73.962565         40.772647                1
# 3             40.790844         -73.965316         40.803349                3
# 4             40.744085         -73.973082         40.761247                5
# ...                 ...                ...               ...              ...
# 199995        40.739367         -73.986525         40.740297                1
# 199996        40.736837         -74.006672         40.739620                1
# 199997        40.756487         -73.858957         40.692588                2
# 199998        40.725452         -73.983215         40.695415                1
# 199999        40.720077         -73.985508         40.768793                1
#
#         hour  day  month  year  dayofweek
# 0         19    7      5  2015          3
# 1         20   17      7  2009          4
# 2         21   24      8  2009          0
# 3          8   26      6  2009          4
# 4         17   28      8  2014          3
# ...      ...  ...    ...   ...        ...
# 199995    10   28     10  2012          6
# 199996     1   14      3  2014          4
# 199997     0   29      6  2009          0
# 199998    14   20      5  2015          2
# 199999     4   15      5  2010          5
#
# [199999 rows x 12 columns]

# %%
data.drop(['pickup_datetime'], axis = 1, inplace=True)

# %%
data.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.925023        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  hour  day  month  year  dayofweek
# 0         40.723217                1    19    7      5  2015          3
# 1         40.750325                1    20   17      7  2009          4
# 2         40.772647                1    21   24      8  2009          0
# 3         40.803349                3     8   26      6  2009          4
# 4         40.761247                5    17   28      8  2014          3

# %%
data.plot(kind='box', subplots=True, layout=(7,2), figsize=(15,20))
# Out:
# fare_amount             Axes(0.125,0.786098;0.352273x0.0939024)
# pickup_longitude     Axes(0.547727,0.786098;0.352273x0.0939024)
# pickup_latitude         Axes(0.125,0.673415;0.352273x0.0939024)
# dropoff_longitude    Axes(0.547727,0.673415;0.352273x0.0939024)
# dropoff_latitude        Axes(0.125,0.560732;0.352273x0.0939024)
# passenger_count      Axes(0.547727,0.560732;0.352273x0.0939024)
# hour                    Axes(0.125,0.448049;0.352273x0.0939024)
# day                  Axes(0.547727,0.448049;0.352273x0.0939024)
# month                   Axes(0.125,0.335366;0.352273x0.0939024)
# year                 Axes(0.547727,0.335366;0.352273x0.0939024)
# dayofweek               Axes(0.125,0.222683;0.352273x0.0939024)
# dtype: object

# %%
def remove_outlier(df, col) :
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    ub = Q3 + 1.5*IQR
    lb = Q1 - 1.5*IQR
    data[col] = np.clip(data[col], lb, ub)
    return df

def remove(df, col_list) :
    for c in col_list :
        df = remove_outlier(data, c)
    return df

# %%
data = remove(data, data.iloc[:, 0::])

# %%
data.duplicated().sum()
# Out:
# 3

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.plot(kind='box', subplots=True, layout=(7,2), figsize=(15,20))
# Out:
# fare_amount             Axes(0.125,0.786098;0.352273x0.0939024)
# pickup_longitude     Axes(0.547727,0.786098;0.352273x0.0939024)
# pickup_latitude         Axes(0.125,0.673415;0.352273x0.0939024)
# dropoff_longitude    Axes(0.547727,0.673415;0.352273x0.0939024)
# dropoff_latitude        Axes(0.125,0.560732;0.352273x0.0939024)
# passenger_count      Axes(0.547727,0.560732;0.352273x0.0939024)
# hour                    Axes(0.125,0.448049;0.352273x0.0939024)
# day                  Axes(0.547727,0.448049;0.352273x0.0939024)
# month                   Axes(0.125,0.335366;0.352273x0.0939024)
# year                 Axes(0.547727,0.335366;0.352273x0.0939024)
# dayofweek               Axes(0.125,0.222683;0.352273x0.0939024)
# dtype: object

# %%
corr = data.corr()
corr
# Out:
#                    fare_amount  pickup_longitude  pickup_latitude  \
# fare_amount           1.000000          0.154063        -0.110868
# pickup_longitude      0.154063          1.000000         0.259634
# pickup_latitude      -0.110868          0.259634         1.000000
# dropoff_longitude     0.218694          0.425571         0.048995
# dropoff_latitude     -0.125886          0.073417         0.515691
# passenger_count       0.015796         -0.013182        -0.012902
# hour                 -0.023603          0.011600         0.029682
# day                   0.004555         -0.003191        -0.001547
# month                 0.030812          0.001170         0.001558
# year                  0.141279          0.010182        -0.014235
# dayofweek             0.013672         -0.024664        -0.042288
#
#                    dropoff_longitude  dropoff_latitude  passenger_count  \
# fare_amount                 0.218694         -0.125886         0.015796
# pickup_longitude            0.425571          0.073417        -0.013182
# pickup_latitude             0.048995          0.515691        -0.012902
# dropoff_longitude           1.000000          0.245796        -0.009284
# dropoff_latitude            0.245796          1.000000        -0.006350
# passenger_count            -0.009284         -0.006350         1.000000
# hour                       -0.046551          0.019756         0.020258
# day                        -0.004006         -0.003501         0.002698
# month                       0.002395         -0.001194         0.010353
# year                        0.011336         -0.009584        -0.009741
# dayofweek                  -0.003355         -0.031916         0.048547
#
#                        hour       day     month      year  dayofweek
# fare_amount       -0.023603  0.004555  0.030812  0.141279   0.013672
# pickup_longitude   0.011600 -0.003191  0.001170  0.010182  -0.024664
# pickup_latitude    0.029682 -0.001547  0.001558 -0.014235  -0.042288
# dropoff_longitude -0.046551 -0.004006  0.002395  0.011336  -0.003355
# dropoff_latitude   0.019756 -0.003501 -0.001194 -0.009584  -0.031916
# passenger_count    0.020258  0.002698  0.010353 -0.009741   0.048547
# hour               1.000000  0.004666 -0.003927  0.002159  -0.086960
# day                0.004666  1.000000 -0.017342 -0.012167   0.005605
# month             -0.003927 -0.017342  1.000000 -0.115859  -0.008780
# year               0.002159 -0.012167 -0.115859  1.000000   0.006106
# dayofweek         -0.086960  0.005605 -0.008780  0.006106   1.000000

# %%
sns.heatmap(data=corr, annot=True)
# Out:
# <Axes: >

# %%
from math import *
def distance(long1, lat1, long2, lat2) :
    dist = []
    for pos in range(len(long1)):
        lo1, la1, lo2, la2 = map(radians,[long1[pos], lat1[pos], long2[pos], lat2[pos]])
        lo = lo2 - lo1
        la = la2 - la1
        a = sin(la/2)**2 + cos(la1)*cos(la2)*sin(lo/2)**2
        c = 2*asin(sqrt(a))*6371
        dist.append(c)
    return dist

# %%
data['traveled'] = distance(data['pickup_longitude'].to_numpy(),
                            data['pickup_latitude'].to_numpy(),
                            data['dropoff_longitude'].to_numpy(),
                            data['dropoff_latitude'].to_numpy())
data.head()
# Out:
#    fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0          7.5        -73.999817        40.738354         -73.999512
# 1          7.7        -73.994355        40.728225         -73.994710
# 2         12.9        -74.005043        40.740770         -73.962565
# 3          5.3        -73.976124        40.790844         -73.965316
# 4         16.0        -73.929790        40.744085         -73.973082
#
#    dropoff_latitude  passenger_count  hour  day  month  year  dayofweek  \
# 0         40.723217              1.0    19    7      5  2015          3
# 1         40.750325              1.0    20   17      7  2009          4
# 2         40.772647              1.0    21   24      8  2009          0
# 3         40.803349              3.0     8   26      6  2009          4
# 4         40.761247              3.5    17   28      8  2014          3
#
#    traveled
# 0  1.683323
# 1  2.457590
# 2  5.036377
# 3  1.661683
# 4  4.115803

# %%
x = data.drop(['fare_amount'], axis=1)
y = data['fare_amount']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33)

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression()
regression.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regression.predict(x_test)
y_pred
# Out:
# array([11.9790321 ,  6.07835846,  9.65454874, ...,  6.2344043 ,
#         6.43027721, 19.4107769 ])

# %%
from sklearn.metrics import r2_score
r2_score(y_pred, y_test)
# Out:
# 0.49074847791633436

# %%
from sklearn.ensemble import RandomForestRegressor
rfr = RandomForestRegressor(n_estimators = 10)

# %%
rfr.fit(x_train, y_train)
Y = rfr.predict(x_test)
Y
# Out:
# array([10.84 ,  5.64 ,  7.47 , ...,  5.49 ,  4.76 , 18.575])

# %%
r2_score(Y, y_test)
# Out:
# 0.7228620719028596

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_pred, y_test)
MSE = mean_squared_error(Y, y_test)
rmse = np.sqrt(mse)
RMSE = np.sqrt(MSE)

# %%
rmse
# Out:
# 3.161643294490984

# %%
RMSE
# Out:
# 2.57348098366177
